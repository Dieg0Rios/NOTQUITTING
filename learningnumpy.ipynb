# %%
import numpy as np
# Out:
# Running cells with 'Python 3.11.9' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Diego Rios Morales/AppData/Local/Microsoft/WindowsApps/python3.11.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# np.array is used to initialize the array of values

# %%
a = np.array([[1,2],[3,6],[4,5]])
# Out:
# Running cells with 'Python 3.11.9' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Diego Rios Morales/AppData/Local/Microsoft/WindowsApps/python3.11.exe" -m pip install ipykernel -U --user --force-reinstall'
